# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import cv2 as cv

# %%
img = cv.imread('C:/Users/Ayush/Desktop/CV with python/New folder/00-puppy.png')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img1 = cv.imread('wrong/path/xyz.jpg')

# %%
type(img1)
# Out:
# NoneType

# %%
img.shape
# Out:
# (1300, 1950, 3)

# %%
plt.imshow(img)

# %%
# MATPLOTLIB --> RED GREEN BLUE
# OPENCV ------> BLUE GREEN RED

# %%
fix_img = cv.cvtColor(img,cv.COLOR_BGR2RGB)  # Used to bgr to rgb as opencv reads the images in different order.
plt.imshow(fix_img)

# %%
img_gray = cv.imread('C:/Users/Ayush/Desktop/CV with python/New folder/00-puppy.png',cv.IMREAD_GRAYSCALE)  #conversion into gray

# %%
img_gray.shape    # Because it's in gray color, and there are no other channels.
# Out:
# (1300, 1950)

# %%
plt.imshow(img_gray,cmap='gray')

# %%
fix_img.shape
# Out:
# (1300, 1950, 3)

# %%
new_img = cv2.resize(fix_img,(1000,400))

# %%
plt.imshow(new_img)

# %%
w_ratio = 0.5
h_ratio = 0.5

# %%
new_image = cv2.resize(fix_img,(0,0),fix_img,w_ratio,h_ratio)

# %%
plt.imshow(new_image)

# %%
new_image.shape
# Out:
# (650, 975, 3)

# %%
new_img = cv.flip(fix_img,0)  # 0,1,-1 = axis
plt.imshow(new_img)

# %%
type(fix_img)
# Out:
# numpy.ndarray

# %%
cv.imwrite('totally_new.png',fix_img)
# Out:
# True

# %%
fig = plt.figure(figsize=(2,2))
ax = fig.add_subplot(111)
ax.imshow(fix_img)
